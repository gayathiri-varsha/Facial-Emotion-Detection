# %%
import cv2 ### pip install opencv-python

# %%
pip install deepface

# %%
from deepface import DeepFace
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11616/2158637665.py in <module>
# ----> 1 from deepface import DeepFace
#
# ModuleNotFoundError: No module named 'deepface'

# %%
img = cv2.imread('attentive.jpg')

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img) ## BGR

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img)
# Out:
# facial_expression_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5
# To: C:\Users\DELL\.deepface\weights\facial_expression_model_weights.h5
# 100%|█████████████████████████████████████████████████████████████████████████████| 5.98M/5.98M [00:02<00:00, 2.54MB/s]
# age_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/age_model_weights.h5
# To: C:\Users\DELL\.deepface\weights\age_model_weights.h5
# 100%|███████████████████████████████████████████████████████████████████████████████| 539M/539M [01:11<00:00, 7.58MB/s]
# gender_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/gender_model_weights.h5
# To: C:\Users\DELL\.deepface\weights\gender_model_weights.h5
# 100%|███████████████████████████████████████████████████████████████████████████████| 537M/537M [02:53<00:00, 3.10MB/s]
# race_model_single_batch.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/race_model_single_batch.h5
# To: C:\Users\DELL\.deepface\weights\race_model_single_batch.h5
# 100%|███████████████████████████████████████████████████████████████████████████████| 537M/537M [01:14<00:00, 7.22MB/s]
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:02<00:00,  1.57it/s]

# %%
predictions
# Out:
# {'emotion': {'angry': 9.437489575016404e-06,
#   'disgust': 1.092070157218414e-11,
#   'fear': 3.997119318414854e-07,
#   'happy': 95.27121158070634,
#   'sad': 5.388667753460804e-05,
#   'surprise': 4.3320865923147965e-06,
#   'neutral': 4.728717266244725},
#  'dominant_emotion': 'happy',
#  'region': {'x': 138, 'y': 263, 'w': 390, 'h': 390},
#  'age': 37,
#  'gender': 'Woman',
#  'race': {'asian': 1.6310525167615721,
#   'indian': 0.017980810278814152,
#   'black': 0.0013911350753636983,
#   'white': 91.37738295658725,
#   'middle eastern': 1.663800986933767,
#   'latino hispanic': 5.308395568036769},
#  'dominant_race': 'white'}

# %%
type(predictions)
# Out:
# dict

# %%
predictions['dominant_emotion']
# Out:
# 'happy'

# %%
faceCascade= cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
  #print(faceCascade.empty())
faces = faceCascade.detectMultiScale(gray,1.1,4)
      # Draw a rectangle around the faces
for(x,y,w,h) in faces:
    cv2.rectangle(img, (x,y), (x+w, y+h), (0, 255, 0), 2)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
font = cv2.FONT_HERSHEY_SIMPLEX
   # use putText() method for
   # inserting text on video
cv2.putText(img,
           predictions['dominant_emotion'],
           (0,50),
           font,1,
           (0,0,255),
           2,
           cv2.LINE_4);

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
img = cv2.imread('disgust.jpg')

# %%
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:01<00:00,  3.24it/s]

# %%
predictions
# Out:
# {'emotion': {'angry': 3.2028948934611616,
#   'disgust': 96.58718088788872,
#   'fear': 0.16729847826725114,
#   'happy': 2.4478337261791524e-06,
#   'sad': 0.0026096833344383475,
#   'surprise': 0.03998247213557196,
#   'neutral': 2.88428185651746e-05},
#  'dominant_emotion': 'disgust',
#  'region': {'x': 214, 'y': 87, 'w': 120, 'h': 120},
#  'age': 23,
#  'gender': 'Man',
#  'race': {'asian': 3.695865347981453,
#   'indian': 13.45195323228836,
#   'black': 0.9500117041170597,
#   'white': 7.057934999465942,
#   'middle eastern': 8.162501454353333,
#   'latino hispanic': 66.68173670768738},
#  'dominant_race': 'latino hispanic'}

# %%
type(predictions)
# Out:
# dict

# %%
predictions['dominant_emotion']
# Out:
# 'disgust'

# %%
faceCascade= cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
  #print(faceCascade.empty())
faces = faceCascade.detectMultiScale(gray,1.1,4)
      # Draw a rectangle around the faces
for(x,y,w,h) in faces:
    cv2.rectangle(img, (x,y), (x+w, y+h), (0, 0, 255), 2)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
font = cv2.FONT_HERSHEY_SIMPLEX
   # use putText() method for
   # inserting text on video
cv2.putText(img,
           predictions['dominant_emotion'],
           (0,50),
           font,1,
           (0,0,255),
           2,
           cv2.LINE_4);

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
faceCascade= cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
cap = cv2.VideoCapture(1)
if not cap.isOpened():
    cap=cv2.VideoCapture(0)
if not cap.isOpened():
    raise IOError("Cannot open Webcam")

# %%
pip install deepface
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: deepface in c:\users\dell\appdata\roaming\python\python310\site-packages (0.0.75)
# Requirement already satisfied: retina-face>=0.0.1 in c:\users\dell\appdata\roaming\python\python310\site-packages (from deepface) (0.0.12)
# Requirement already satisfied: mtcnn>=0.1.0 in c:\users\dell\appdata\roaming\python\python310\site-packages (from deepface) (0.1.1)
# Requirement already satisfied: tqdm>=4.30.0 in c:\users\dell\appdata\roaming\python\python310\site-packages (from deepface) (4.64.0)
# Requirement already satisfied: pandas>=0.23.4 in c:\users\dell\appdata\roaming\python\python310\site-packages (from deepface) (1.4.2)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: tensorflow>=1.9.0 in c:\users\dell\appdata\roaming\python\python310\site-packages (from deepface) (2.9.1)
# Requirement already satisfied: Flask>=1.1.2 in c:\users\dell\appdata\roaming\python\python310\site-packages (from deepface) (2.2.1)
# Requirement already satisfied: fire>=0.4.0 in c:\users\dell\appdata\roaming\python\python310\site-packages (from deepface) (0.4.0)
# Requirement already satisfied: Pillow>=5.2.0 in c:\users\dell\appdata\roaming\python\python310\site-packages (from deepface) (9.1.0)
# Requirement already satisfied: opencv-python>=4.5.5.64 in c:\users\dell\appdata\roaming\python\python310\site-packages (from deepface) (4.6.0.66)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\dell\appdata\roaming\python\python310\site-packages (from deepface) (1.22.3)
# Requirement already satisfied: gdown>=3.10.1 in c:\users\dell\appdata\roaming\python\python310\site-packages (from deepface) (4.5.1)
# Requirement already satisfied: keras>=2.2.0 in c:\users\dell\appdata\roaming\python\python310\site-packages (from deepface) (2.9.0)
# Requirement already satisfied: six in c:\users\dell\appdata\roaming\python\python310\site-packages (from fire>=0.4.0->deepface) (1.16.0)
# Requirement already satisfied: termcolor in c:\users\dell\appdata\roaming\python\python310\site-packages (from fire>=0.4.0->deepface) (1.1.0)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\dell\appdata\roaming\python\python310\site-packages (from Flask>=1.1.2->deepface) (2.1.2)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\dell\appdata\roaming\python\python310\site-packages (from Flask>=1.1.2->deepface) (3.1.2)
# Requirement already satisfied: Werkzeug>=2.2.0 in c:\users\dell\appdata\roaming\python\python310\site-packages (from Flask>=1.1.2->deepface) (2.2.1)
# Requirement already satisfied: click>=8.0 in c:\users\dell\appdata\roaming\python\python310\site-packages (from Flask>=1.1.2->deepface) (8.1.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\dell\appdata\roaming\python\python310\site-packages (from gdown>=3.10.1->deepface) (4.11.1)
# Requirement already satisfied: requests[socks] in c:\users\dell\appdata\roaming\python\python310\site-packages (from gdown>=3.10.1->deepface) (2.28.1)
# Requirement already satisfied: filelock in c:\users\dell\appdata\roaming\python\python310\site-packages (from gdown>=3.10.1->deepface) (3.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\dell\appdata\roaming\python\python310\site-packages (from pandas>=0.23.4->deepface) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\appdata\roaming\python\python310\site-packages (from pandas>=0.23.4->deepface) (2022.1)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\dell\appdata\roaming\python\python310\site-packages (from tensorflow>=1.9.0->deepface) (1.14.1)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\dell\appdata\roaming\python\python310\site-packages (from tensorflow>=1.9.0->deepface) (0.2.0)
# Requirement already satisfied: setuptools in c:\program files\python310\lib\site-packages (from tensorflow>=1.9.0->deepface) (58.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\dell\appdata\roaming\python\python310\site-packages (from tensorflow>=1.9.0->deepface) (4.3.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\dell\appdata\roaming\python\python310\site-packages (from tensorflow>=1.9.0->deepface) (1.47.0)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in c:\users\dell\appdata\roaming\python\python310\site-packages (from tensorflow>=1.9.0->deepface) (2.9.1)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\dell\appdata\roaming\python\python310\site-packages (from tensorflow>=1.9.0->deepface) (1.1.2)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\dell\appdata\roaming\python\python310\site-packages (from tensorflow>=1.9.0->deepface) (0.26.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\dell\appdata\roaming\python\python310\site-packages (from tensorflow>=1.9.0->deepface) (3.19.4)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\dell\appdata\roaming\python\python310\site-packages (from tensorflow>=1.9.0->deepface) (1.0.0)
# Requirement already satisfied: packaging in c:\users\dell\appdata\roaming\python\python310\site-packages (from tensorflow>=1.9.0->deepface) (21.3)
# Requirement already satisfied: flatbuffers<2,>=1.12 in c:\users\dell\appdata\roaming\python\python310\site-packages (from tensorflow>=1.9.0->deepface) (1.12)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\dell\appdata\roaming\python\python310\site-packages (from tensorflow>=1.9.0->deepface) (3.7.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\dell\appdata\roaming\python\python310\site-packages (from tensorflow>=1.9.0->deepface) (1.6.3)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in c:\users\dell\appdata\roaming\python\python310\site-packages (from tensorflow>=1.9.0->deepface) (2.9.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\dell\appdata\roaming\python\python310\site-packages (from tensorflow>=1.9.0->deepface) (3.3.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\dell\appdata\roaming\python\python310\site-packages (from tensorflow>=1.9.0->deepface) (0.4.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\dell\appdata\roaming\python\python310\site-packages (from tensorflow>=1.9.0->deepface) (14.0.6)
# Requirement already satisfied: colorama in c:\users\dell\appdata\roaming\python\python310\site-packages (from tqdm>=4.30.0->deepface) (0.4.5)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\dell\appdata\roaming\python\python310\site-packages (from astunparse>=1.6.0->tensorflow>=1.9.0->deepface) (0.37.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dell\appdata\roaming\python\python310\site-packages (from Jinja2>=3.0->Flask>=1.1.2->deepface) (2.1.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\dell\appdata\roaming\python\python310\site-packages (from tensorboard<2.10,>=2.9->tensorflow>=1.9.0->deepface) (3.4.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\dell\appdata\roaming\python\python310\site-packages (from tensorboard<2.10,>=2.9->tensorflow>=1.9.0->deepface) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\dell\appdata\roaming\python\python310\site-packages (from tensorboard<2.10,>=2.9->tensorflow>=1.9.0->deepface) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\dell\appdata\roaming\python\python310\site-packages (from tensorboard<2.10,>=2.9->tensorflow>=1.9.0->deepface) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\dell\appdata\roaming\python\python310\site-packages (from tensorboard<2.10,>=2.9->tensorflow>=1.9.0->deepface) (2.10.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\dell\appdata\roaming\python\python310\site-packages (from beautifulsoup4->gdown>=3.10.1->deepface) (2.3.2.post1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\dell\appdata\roaming\python\python310\site-packages (from packaging->tensorflow>=1.9.0->deepface) (3.0.9)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\dell\appdata\roaming\python\python310\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (2.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\appdata\roaming\python\python310\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\dell\appdata\roaming\python\python310\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\appdata\roaming\python\python310\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (2022.6.15)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\dell\appdata\roaming\python\python310\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (1.7.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\dell\appdata\roaming\python\python310\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=1.9.0->deepface) (5.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\dell\appdata\roaming\python\python310\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=1.9.0->deepface) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\dell\appdata\roaming\python\python310\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=1.9.0->deepface) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\dell\appdata\roaming\python\python310\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow>=1.9.0->deepface) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\dell\appdata\roaming\python\python310\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=1.9.0->deepface) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\dell\appdata\roaming\python\python310\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow>=1.9.0->deepface) (3.2.0)

# %%
import cv2 
from deepface import DeepFace

faceCascade= cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

cap = cv2.VideoCapture(1)
if not cap.isOpened():
    cap=cv2.VideoCapture(0)
if not cap.isOpened():
    raise IOError("Cannot open Webcam")
    
while True:
    ret,frame= cap.read() 
    result =DeepFace.analyze(frame, actions = ['emotion'])
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    #print(faceCascade.empty())
    faces = faceCascade.detectMultiScale(gray,1.1,4)
      # Draw a rectangle around the faces
    for(x,y,w,h) in faces:
      cv2.rectangle(frame, (x,y), (x+w, y+h), (0, 0, 255), 2)
    font = cv2.FONT_HERSHEY_SIMPLEX
   # use putText() method for
   # inserting text on video
    cv2.putText(frame,
                result['dominant_emotion'],
                (50,50),
                font,3,
                (0,0,255),
                2,
                cv2.LINE_4)
    cv2.imshow('Original video',frame)
    
    if cv2.waitKey(2) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\DELL\Live in Lab\Face detection\.ipynb_checkpoints\face detection-checkpoint.ipynb Cell 34 in <cell line: 12>()
#      <a href='vscode-notebook-cell:/c%3A/Users/DELL/Live%20in%20Lab/Face%20detection/.ipynb_checkpoints/face%20detection-checkpoint.ipynb#X45sZmlsZQ%3D%3D?line=11'>12</a> while True:
#      <a href='vscode-notebook-cell:/c%3A/Users/DELL/Live%20in%20Lab/Face%20detection/.ipynb_checkpoints/face%20detection-checkpoint.ipynb#X45sZmlsZQ%3D%3D?line=12'>13</a>     ret,frame= cap.read()
# ---> <a href='vscode-notebook-cell:/c%3A/Users/DELL/Live%20in%20Lab/Face%20detection/.ipynb_checkpoints/face%20detection-checkpoint.ipynb#X45sZmlsZQ%3D%3D?line=13'>14</a>     result =DeepFace.analyze(frame, actions = ['emotion'])
#      <a href='vscode-notebook-cell:/c%3A/Users/DELL/Live%20in%20Lab/Face%20detection/.ipynb_checkpoints/face%20detection-checkpoint.ipynb#X45sZmlsZQ%3D%3D?line=14'>15</a>     gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#      <a href='vscode-notebook-cell:/c%3A/Users/DELL/Live%20in%20Lab/Face%20detection/.ipynb_checkpoints/face%20detection-checkpoint.ipynb#X45sZmlsZQ%3D%3D?line=15'>16</a>     #print(faceCascade.empty())
#
# File ~\AppData\Roaming\Python\Python310\site-packages\deepface\DeepFace.py:393, in analyze(img_path, actions, models, enforce_detection, detector_backend, prog_bar)
#     391 if action == 'emotion':
#     392 	emotion_labels = ['angry', 'disgust', 'fear', 'happy', 'sad', 'surprise', 'neutral']
# --> 393 	img, region = functions.preprocess_face(img = img_path, target_size = (48, 48), grayscale = True, enforce_detection = enforce_detection, detector_backend = detector_backend, return_region = True)
#     395 	emotion_predictions = models['emotion'].predict(img)[0,:]
#     397 	sum_of_predictions = emotion_predictions.sum()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\deepface\commons\functions.py:178, in preprocess_face(img, target_size, grayscale, enforce_detection, detector_backend, return_region, align)
#     175 img = load_image(img)
#     176 base_img = img.copy()
# --> 178 img, region = detect_face(img = img, detector_backend = detector_backend, grayscale = grayscale, enforce_detection = enforce_detection, align = align)
#     180 #--------------------------
#     182 if img.shape[0] == 0 or img.shape[1] == 0:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\deepface\commons\functions.py:124, in detect_face(img, detector_backend, grayscale, enforce_detection, align)
#     122 	return img, img_region
#     123 else:
# --> 124 	raise ValueError("Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.")
#
# ValueError: Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import cv2
import numpy as np
path = "haarcascade_frontalface_default.xml"
font_scale = 1.5
font = cv2.FONT_HERSHEY_PLAIN

rectangle_bgr=(255,255,255)
img = np.zeros((500,500))
text = "Some text in a box!"
(text_width, text_height) = cv2.getTextSize(text, font, fontScale=font_scale, thickness=1)[0]
text_offset_x = 10
text_offset_y = img.shape[0] - 25
box_coords = ((text_offset_x, text_offset_y),(text_offset_x + text_width + 2, text_offset_y - text_height -2))
cv2.rectangle(img, box_coords[0], box_coords[1], rectangle_bgr, cv2.FILLED)
cv2.putText(img, text, (text_offset_x, text_offset_y), font, fontScale=font_scale, color=(0, 0, 0),thickness=1)

cap=cv2.VideoCapture(1)
if not cap.isOpened():
    cap = cv2.VideoCapture(0)
if not cap.isOpened():
    raise IOError("Cannot open webcam")

while True:
    ret,frame = cap.read()
    faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces= faceCascade.detectMultiScale(gray,1.1,4)
    for x,y,w,h in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = frame[y:y+h, x:x+w]
        cv2.rectangle(frame, (x, y), (x+w, y+h), (255,0,0),2)
        facess = faceCascade.detectMultiScale(roi_gray)
        if len(facess)==0:
            print("Face not detected")
        else:
            for(ex,ey,ew,eh) in facess:
                face_roi = roi_color[ey: ey+eh, ex:ex +ew]
                final_image= cv2.resize(face_roi, (224,224))
    final_image= cv2.resize(frame, (224,224))
    final_image=  np.expand_dims(final_image, axis=0)
    final_image=final_image/255.0

    font= cv2.FONT_HERSHEY_SIMPLEX

    Predictions = new_model.predict(final_image)
    front_scale =1.5
    font = cv2.FONT_HERSHEY_PLAIN

    if (np.argmax(Predictions)==0):
     status="Angry"

     x1,y1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\DELL\Live in Lab\Face detection\.ipynb_checkpoints\face detection-checkpoint.ipynb Cell 35 in <cell line: 23>()
#      <a href='vscode-notebook-cell:/c%3A/Users/DELL/Live%20in%20Lab/Face%20detection/.ipynb_checkpoints/face%20detection-checkpoint.ipynb#X46sZmlsZQ%3D%3D?line=40'>41</a> final_image=final_image/255.0
#      <a href='vscode-notebook-cell:/c%3A/Users/DELL/Live%20in%20Lab/Face%20detection/.ipynb_checkpoints/face%20detection-checkpoint.ipynb#X46sZmlsZQ%3D%3D?line=42'>43</a> font= cv2.FONT_HERSHEY_SIMPLEX
# ---> <a href='vscode-notebook-cell:/c%3A/Users/DELL/Live%20in%20Lab/Face%20detection/.ipynb_checkpoints/face%20detection-checkpoint.ipynb#X46sZmlsZQ%3D%3D?line=44'>45</a> Predictions = new_model.predict(final_image)
#      <a href='vscode-notebook-cell:/c%3A/Users/DELL/Live%20in%20Lab/Face%20detection/.ipynb_checkpoints/face%20detection-checkpoint.ipynb#X46sZmlsZQ%3D%3D?line=45'>46</a> front_scale =1.5
#      <a href='vscode-notebook-cell:/c%3A/Users/DELL/Live%20in%20Lab/Face%20detection/.ipynb_checkpoints/face%20detection-checkpoint.ipynb#X46sZmlsZQ%3D%3D?line=46'>47</a> font = cv2.FONT_HERSHEY_PLAIN
#
# NameError: name 'new_model' is not defined
